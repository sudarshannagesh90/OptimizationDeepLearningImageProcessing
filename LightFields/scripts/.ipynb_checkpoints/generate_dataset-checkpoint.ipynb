# %%
# %matplotlib inline
import sys
sys.path.insert(0, '/home/snagesh/git/OptimizationDeepLearningImageProcessing/')
import h5py
import numpy as np
import os
from LightFields.utils import data as data_utils
import matplotlib.pyplot as plt 
import torch
import torch.nn as nn
from torch.autograd import Variable
import scipy.ndimage as im
import time

# %%
destination_path     = "/home/snagesh/git/OptimizationDeepLearningImageProcessing/LightFields/h5Files/"
data_source_path     = "/home/snagesh/git/OptimizationDeepLearningImageProcessing/LightFields/xmlFiles/"

# %%
## File-names  
filenames = ["airboat","al","alfa147","cessna","cube","diamond","dodecahedron","gourd","humanoid_quad","humanoid_tri","icosahedron","lamp","magnolia","minicooper","octahedron","power_lines","roi","sandal","shuttle","skyscraper","slot_machine","teapot","tetrahedron","violin_case"]
dataset_name        = ["generatedLightFields"]

# %%
data_utils.create_dataset(data_source_path, filenames, destination_path, dataset_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-c3923e2ca535> in <module>()
# ----> 1 data_utils.create_dataset(data_source_path, filenames, destination_path, dataset_name)
#
# ~/git/OptimizationDeepLearningImageProcessing/LightFields/utils/data.py in create_dataset(data_source_path, filenames, destination_path, dataset_name)
#     145         for i in range(len(filenames)):
#     146                 gif_name          = os.path.join(data_source_path,filenames[i],filenames[i]+".gif")
# --> 147                 hr_image.append(extract_frames(gif_name))
#     148                 img = cv2.imread(os.path.join(data_source_path,filenames[i],filenames[i]+"00.png"),0)
#     149                 lr_image.append(img)
#
# ~/git/OptimizationDeepLearningImageProcessing/LightFields/utils/data.py in extract_frames(inGif)
#     184                 try:
# ...

# %%
data_source_path     = "/data/UG2_data/imagenet_compressed"
dataset_name = os.listdir(data_source_path)[1]

with h5py.File(os.path.join(data_source_path, dataset_name),'r') as file:
    data = np.array(file["data"])
    label= np.array(file["label"])
for imageIndex in range(10):
    testImage = data[imageIndex]
    testImage = np.transpose(testImage.astype(np.uint8), (1, 2, 0))
    GTImage = label[imageIndex]
    GTImage = np.transpose(GTImage.astype(np.uint8), (1, 2, 0))
    plt.figure(figsize=(15,15))
    plt.subplot(121)
    plt.imshow(GTImage)
    plt.subplot(122)
    plt.imshow(testImage)

# %%
a = [1,2,3,4,5,6]
print(a[0:3])
print(a[3:])
# Out:
# [1, 2, 3]
# [4, 5, 6]

# %%
def extract_frames(inGif):
	frame = Image.open(inGif)
	nframes = 0
	while frame:
		try:
			tempImage = frame.seek(nframes)
			print(tempImage.dtype)
			print(tempImage.size)
			im[:,:,:,nframes] = tempImage            
			nframes +=1
		except EOFError:
			break;
	return im

# %%
hr_image = []
gif_name          = os.path.join(data_source_path,filenames[0],filenames[0]+".gif")
frame = Image.open(gif_name)

# %%
tempImage = frame.seek(0)
tempImage.save('output.png')
